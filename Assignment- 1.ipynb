# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:\Users\User\Desktop\Siam's\old code\Salary Data.csv")

# %%
data.head()
# Out:
#    Experience Years  Salary
# 0               1.1   39343
# 1               1.2   42774
# 2               1.3   46205
# 3               1.5   37731
# 4               2.0   43525

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
y = data.drop('Experience Years' , axis= 1)

# %%
X = data[['Experience Years']]

# %%
X.mean()
y.mean()
# Out:
# Salary       74743.6250
# Predict_y        5.1525
# dtype: float64

# %%
reg.fit(X, y)
# Out:
# LinearRegression()

# %%
X.head()
# Out:
#    Experience Years
# 0               1.1
# 1               1.2
# 2               1.3
# 3               1.5
# 4               2.0

# %%
y.head()
# Out:
#    Salary  Predict_y
# 0   39343   1.599367
# 1   42774   1.943733
# 2   46205   2.288100
# 3   37731   1.437571
# 4   43525   2.019111

# %%
m = reg.coef_
c = reg.intercept_

# %%
m
# Out:
# array([[9.52365051e+03],
#        [9.55881445e-01]])

# %%
c
# Out:
# array([2.56730158e+04, 2.27320854e-01])

# %%
data['Predict_y'] = reg.predict(X)

# %%
data.head()
# Out:
#    Experience Years  Salary     Predict_y
# 0               1.1   39343  36149.031319
# 1               1.2   42774  37101.396369
# 2               1.3   46205  38053.761420
# 3               1.5   37731  39958.491522
# 4               2.0   43525  44720.316775

# %%
reg.score(X, y)
# Out:
# 0.9558814451799361

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
score = r2_score(y, reg.predict(X))

# %%
score
# Out:
# 0.9558814451799361

# %%
print('The score nambar is :' , score)
# Out:
# The score nambar is : 0.9558814451799361
